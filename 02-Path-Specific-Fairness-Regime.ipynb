# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os

FRAC_ADMIT = 0.5

# %%
###
## Load dataframe where each row is a single applicant
###

df = pd.read_csv('./df_test.csv')
df['key'] = df['R'].astype(str) + "_"  + df['T'].astype(str)

###
## Estimate E[Y(1)|T, A]
###

df_train = pd.read_csv('./df_train.csv')
df_stratum_utility = df_train[['R','T','Y']].groupby(['R','T']).mean().reset_index()
df_stratum_utility['key'] = df_stratum_utility['R'].astype(str) + "_" + df_stratum_utility['T'].astype(str)

# %%
df
# Out:
#        Unnamed: 0  R   E_noise  E_minority  E_majority   M_noise  M_minority  \
# 0               1  1 -0.938105   -0.938105    0.061895  0.215945   -1.722160
# 1               2  0 -0.215684   -0.215684    0.784316 -1.761788   -2.977472
# 2               3  1 -1.542129   -1.542129   -0.542129  0.199073   -2.343056
# 3               4  0 -0.184196   -0.184196    0.815804 -0.364763   -1.548960
# 4               5  0 -0.185605   -0.185605    0.814395 -0.844032   -2.029637
# ...           ... ..       ...         ...         ...       ...         ...
# 99995       99996  0  0.349999    0.349999    1.349999  0.906798    0.256797
# 99996       99997  0 -1.629547   -1.629547   -0.629547  0.520194   -2.109353
# 99997       99998  1  0.633374    0.633374    1.633374  0.901603    0.534977
# 99998       99999  1 -0.006398   -0.006398    0.993602 -1.946521   -2.952919
# 99999      100000  0  0.489667    0.489667    1.489667  1.974965    1.464631
#
#        M_majority    T_noise  T_minority  ...         E         M   T  \
# 0       -0.722160  13.309506          54  ... -0.938105 -1.722160  54
# 1       -1.977472   2.297927          40  ...  0.784316 -1.977472  46
# 2       -1.343056  10.278808          48  ... -1.542129 -2.343056  48
# 3       -0.548960  -1.428977          42  ...  0.815804 -0.548960  49
# 4       -1.029637   0.621351          42  ...  0.814395 -1.029637  49
# ...           ...        ...         ...  ...       ...       ...  ..
# 99995    1.256797  -2.661217          50  ...  1.349999  1.256797  59
# 99996   -1.109353  -6.607599          32  ... -0.629547 -1.109353  37
# 99997    1.534977 -10.798860          44  ...  0.633374  0.534977  44
# 99998   -1.952919   7.504577          46  ... -0.006398 -2.952919  46
# 99999    2.464631  11.032959          70  ...  1.489667  2.464631  81
#
#          Y_unif  Y_reject_noise  Y     Y_raw  Y_reject  Y_reject_raw   key
# 0      0.028157       -0.149788  1  0.151593         1      0.097778  1_54
# 1      0.304996       -0.304509  0  0.121589         0      0.077453  0_46
# 2      0.584847       -0.233883  0  0.087619         0      0.055041  1_48
# 3      0.257116       -1.287469  1  0.366106         1      0.259425  0_49
# 4      0.945113       -0.620538  0  0.263154         0      0.178047  0_49
# ...         ...             ... ..       ...       ...           ...   ...
# 99995  0.777428       -0.930367  1  0.778474         0      0.680658  0_59
# 99996  0.708348       -0.479244  0  0.247991         0      0.166678  0_37
# 99997  0.999059       -0.834216  0  0.630643         0      0.508743  1_44
# 99998  0.122743       -0.452433  0  0.049599         0      0.030682  1_46
# 99999  0.457278       -0.258257  1  0.921625         1      0.877033  0_81
#
# [100000 rows x 23 columns]

# %%
FRAC_ADMIT = 0.5#df[['A']].sum()/len(df)

# %%
TOTAL_ADMITS = int(len(df)*FRAC_ADMIT)
MAX_BLACK_ADMITS = len(df[df['R']==1])
MIN_GRADUATES = 10000
GRID_SIZE = 100

outcomes_grid = []
Xs = []
Ys = []

for N_black_admits in range(0,MAX_BLACK_ADMITS):
    
    if N_black_admits % GRID_SIZE != 0:
        continue
    
    black_admits = df[df['R']==1].sort_values(by='T',ascending=False).head(n=N_black_admits)
    white_admits = df[df['R']==0].sort_values(by='T',ascending=False).head(n=TOTAL_ADMITS-N_black_admits)
    
    Y = black_admits['Y'].sum() + white_admits['Y'].sum()
    
    Xs.append(N_black_admits)
    Ys.append(Y)
    print(N_black_admits,Y)
    
    for y_iter in np.arange(MIN_GRADUATES,Y,GRID_SIZE):
        outcomes_grid.append({'min_black_admits':N_black_admits-GRID_SIZE/2, 'max_black_admits':N_black_admits+GRID_SIZE/2, 'max_graduates':y_iter+GRID_SIZE, 'min_graduates':y_iter, 'policy_exists':'Unknown'})
# Out:
# 0 29333
# 100 29381
# 200 29447
# 300 29503
# 400 29542
# 500 29595
# 600 29637
# 700 29682
# 800 29719
# 900 29756
# 1000 29802
# 1100 29842
# 1200 29883
# 1300 29908
# 1400 29943
# 1500 29968
# 1600 29996
# 1700 30028
# 1800 30045
# 1900 30084
# 2000 30102
# 2100 30142
# 2200 30181
# 2300 30206
# 2400 30235
# 2500 30260
# 2600 30285
# 2700 30306
# 2800 30335
# 2900 30359
# 3000 30386
# 3100 30423
# 3200 30451
# 3300 30475
# 3400 30511
# 3500 30536
# 3600 30545
# 3700 30560
# 3800 30580
# 3900 30594
# 4000 30608
# 4100 30638
# 4200 30646
# 4300 30662
# 4400 30672
# 4500 30686
# 4600 30709
# 4700 30732
# 4800 30750
# 4900 30778
# 5000 30785
# 5100 30788
# 5200 30785
# 5300 30792
# 5400 30805
# 5500 30817
# 5600 30828
# 5700 30836
# 5800 30846
# 5900 30865
# 6000 30863
# 6100 30881
# 6200 30893
# 6300 30903
# 6400 30916
# 6500 30915
# 6600 30921
# 6700 30930
# 6800 30932
# 6900 30939
# 7000 30951
# 7100 30953
# 7200 30959
# 7300 30969
# 7400 30971
# 7500 30971
# 7600 30979
# 7700 30979
# 7800 30961
# 7900 30965
# 8000 30970
# 8100 30966
# 8200 30967
# 8300 30978
# 8400 30979
# 8500 30979
# 8600 30989
# 8700 30975
# 8800 30976
# 8900 30962
# 9000 30959
# 9100 30944
# 9200 30935
# 9300 30937
# 9400 30943
# 9500 30928
# 9600 30917
# 9700 30899
# 9800 30896
# 9900 30891
# 10000 30890
# 10100 30901
# 10200 30884
# 10300 30878
# 10400 30876
# 10500 30881
# 10600 30857
# 10700 30853
# 10800 30849
# 10900 30842
# 11000 30839
# 11100 30837
# 11200 30827
# 11300 30823
# 11400 30812
# 11500 30790
# 11600 30782
# 11700 30762
# 11800 30751
# 11900 30734
# 12000 30728
# 12100 30724
# 12200 30723
# 12300 30713
# 12400 30697
# 12500 30690
# 12600 30670
# 12700 30669
# 12800 30657
# 12900 30650
# 13000 30641
# 13100 30635
# 13200 30624
# 13300 30603
# 13400 30598
# 13500 30584
# 13600 30571
# 13700 30564
# 13800 30553
# 13900 30538
# 14000 30525
# 14100 30506
# 14200 30489
# 14300 30478
# 14400 30460
# 14500 30453
# 14600 30439
# 14700 30424
# 14800 30407
# 14900 30399
# 15000 30392
# 15100 30385
# 15200 30385
# 15300 30360
# 15400 30346
# 15500 30335
# 15600 30311
# 15700 30288
# 15800 30276
# 15900 30249
# 16000 30240
# 16100 30217
# 16200 30199
# 16300 30188
# 16400 30157
# 16500 30149
# 16600 30133
# 16700 30107
# 16800 30085
# 16900 30061
# 17000 30049
# 17100 30030
# 17200 30013
# 17300 30000
# 17400 29987
# 17500 29963
# 17600 29950
# 17700 29921
# 17800 29890
# 17900 29862
# 18000 29841
# 18100 29822
# 18200 29797
# 18300 29766
# 18400 29748
# 18500 29719
# 18600 29690
# 18700 29662
# 18800 29633
# 18900 29605
# 19000 29584
# 19100 29563
# 19200 29548
# 19300 29512
# 19400 29494
# 19500 29465
# 19600 29441
# 19700 29408
# 19800 29378
# 19900 29355
# 20000 29331
# 20100 29304
# 20200 29275
# 20300 29240
# 20400 29213
# 20500 29178
# 20600 29147
# 20700 29119
# 20800 29096
# 20900 29067
# 21000 29039
# 21100 29013
# 21200 28991
# 21300 28962
# 21400 28935
# 21500 28907
# 21600 28882
# 21700 28842
# 21800 28807
# 21900 28765
# 22000 28733
# 22100 28702
# 22200 28660
# 22300 28623
# 22400 28591
# 22500 28559
# 22600 28518
# 22700 28485
# 22800 28455
# 22900 28420
# 23000 28392
# 23100 28367
# 23200 28324
# 23300 28292
# 23400 28252
# 23500 28221
# 23600 28190
# 23700 28161
# 23800 28133
# 23900 28094
# 24000 28067
# 24100 28042
# 24200 28017
# 24300 27969
# 24400 27925
# 24500 27888
# 24600 27853
# 24700 27815
# 24800 27779
# 24900 27727
# 25000 27693
# 25100 27659
# 25200 27615
# 25300 27575
# 25400 27530
# 25500 27496
# 25600 27447
# 25700 27409
# 25800 27371
# 25900 27333
# 26000 27284
# 26100 27226
# 26200 27177
# 26300 27137
# 26400 27084
# 26500 27054
# 26600 27011
# 26700 26961
# 26800 26922
# 26900 26876
# 27000 26835
# 27100 26794
# 27200 26750
# 27300 26712
# 27400 26672
# 27500 26624
# 27600 26588
# 27700 26542
# 27800 26496
# 27900 26445
# 28000 26404
# 28100 26367
# 28200 26312
# 28300 26267
# 28400 26220
# 28500 26170
# 28600 26126
# 28700 26075
# 28800 26023
# 28900 25974
# 29000 25929
# 29100 25871
# 29200 25822
# 29300 25761
# 29400 25715
# 29500 25678
# 29600 25629
# 29700 25582
# 29800 25538
# 29900 25485
# 30000 25447
# 30100 25400
# 30200 25358
# 30300 25307
# 30400 25246
# 30500 25199
# 30600 25152
# 30700 25099
# 30800 25051
# 30900 24998
# 31000 24945
# 31100 24888
# 31200 24839
# 31300 24788
# 31400 24736
# 31500 24673
# 31600 24625
# 31700 24570
# 31800 24518
# 31900 24457
# 32000 24390
# 32100 24339
# 32200 24288
# 32300 24231
# 32400 24168
# 32500 24117
# 32600 24057
# 32700 24000
# 32800 23939
# 32900 23884
# 33000 23825
# 33100 23770

# %%
df_pareto = pd.DataFrame({'# Black Admits':Xs, '# Graduates':Ys})

# %%
dff = df[['R','T','Y']].groupby(['R','T']).count().reset_index()
dff.columns = ['R','T','N']
dff['key'] = dff['R'].astype(str) + "_" + dff['T'].astype(str)
dff2 = df[['R','T','Y']].groupby(['R','T']).mean().reset_index()
dff2.columns = ['R','T','Y']
dff2['key'] = dff['R'].astype(str) + "_" + dff['T'].astype(str)
dff = dff.merge(dff2[['key','Y']],on='key')

# %% [markdown]
# ### Setup optimization problem

# %%
from ortools.linear_solver import pywraplp

# %%
solver = pywraplp.Solver.CreateSolver('GLOP')

# %%
dff
# Out:
#      R    T  N    key    Y
# 0    0   12  1   0_12  0.0
# 1    0   14  1   0_14  0.0
# 2    0   15  2   0_15  0.0
# 3    0   16  2   0_16  0.0
# 4    0   17  4   0_17  0.0
# ..  ..  ... ..    ...  ...
# 188  1   94  1   1_94  0.0
# 189  1   95  1   1_95  1.0
# 190  1   97  1   1_97  1.0
# 191  1  101  1  1_101  1.0
# 192  1  104  1  1_104  1.0
#
# [193 rows x 5 columns]

# %%
applicant_stratum = []
vars_cache = {}

# Objective: Maximize the expected utility of the admitted students
objective = solver.Objective()

# For each stratum
for ix, row in dff.iterrows():
    # probability of admission
    numvar = solver.NumVar(0.0, 1.0, str(ix))
    
    # store variable by index, and also by stratum R, T
    applicant_stratum.append(numvar)
    vars_cache[(row['R'],row['T'])] = numvar
    
    # Benefit of admitting people is total utility in that stratum
    objective.SetCoefficient(applicant_stratum[ix], float(row['N']))
objective.SetMaximization()

# %%
# Currently we have no constraints 
solver.NumConstraints()
# Out:
# 0

# %%
# Constraint: At most K applicants
K = int(len(df)*FRAC_ADMIT)
print(K)
admit_quota = solver.Constraint(0, K)

# Total applicants cannot exceed K 
for ix, row in dff.iterrows():
    admit_quota.SetCoefficient(applicant_stratum[ix], float(row['N']))
# Out:
# 50000

# %%
# Now we have one constraint
solver.NumConstraints()
# Out:
# 1

# %% [markdown]
# ## Add CF Fair constraints

# %%
from collections import Counter

def convertListToProb(raw_list):
    counts = dict(Counter(raw_list))
    probs = {}
    for test_score in counts:
        probs[test_score]  = counts[test_score]/float(len(raw_list))
    return [(probs[t], t) for t in probs]

# %%
T_minoritys_list = df[df['R']==0][['T','T_minority_star']].groupby('T')['T_minority_star'].apply(list).reset_index(name='T_minoritys')

# %%
T_minoritys_list['probs'] = T_minoritys_list['T_minoritys'].apply(convertListToProb)

# %%
T_minoritys_list
# Out:
#        T       T_minoritys                                              probs
# 0     12              [12]                                        [(1.0, 12)]
# 1     14              [15]                                        [(1.0, 15)]
# 2     15          [14, 14]                                        [(1.0, 14)]
# 3     16          [13, 13]                                        [(1.0, 13)]
# 4     17  [15, 18, 15, 17]                [(0.5, 15), (0.25, 18), (0.25, 17)]
# ..   ...               ...                                                ...
# 99   112   [103, 103, 104]  [(0.6666666666666666, 103), (0.333333333333333...
# 100  113        [104, 104]                                       [(1.0, 104)]
# 101  114             [105]                                       [(1.0, 105)]
# 102  116             [108]                                       [(1.0, 108)]
# 103  117             [108]                                       [(1.0, 108)]
#
# [104 rows x 3 columns]

# %%
didntexist = 0
exists = 0
for ix, row in T_minoritys_list.iterrows():
    cf_fair_stratum = solver.Constraint(0.0, 0.0)

    majority_T = row['T']
    minoritys_Ts = row['probs']
    
    cf_fair_stratum.SetCoefficient(vars_cache[(0.0, majority_T)], -1.0)
    for prob in minoritys_Ts:
        if (1.0, prob[1]) not in vars_cache:
            vars_cache[(1.0, prob[1])] = solver.NumVar(0.0, 1.0, str((1.0, prob[1])))
            didntexist+=1
        else:
            exists+=1
        cf_fair_stratum.SetCoefficient(vars_cache[(1.0, prob[1])], prob[0])

# %%
didntexist,exists
# Out:
# (9, 542)

# %%
T_majoritys_list = df[df['R']==1][['T','T_majority_star']].groupby('T')['T_majority_star'].apply(list).reset_index(name='T_majoritys')

# %%
T_majoritys_list['probs'] = T_majoritys_list['T_majoritys'].apply(convertListToProb)

# %%
didntexist = 0
exists = 0

for ix, row in T_majoritys_list.iterrows():
    cf_fair_stratum = solver.Constraint(0.0, 0.0)

    minority_T = row['T']
    majority_Ts = row['probs']
    
    cf_fair_stratum.SetCoefficient(vars_cache[(1.0, minority_T)], -1.0)
    for prob in majority_Ts:
        if (0.0, prob[1]) not in vars_cache:
            vars_cache[(0.0, prob[1])] = solver.NumVar(0.0, 1.0, str((0.0, prob[1])))
            didntexist+=1
        else:
            exists+=1
            
        cf_fair_stratum.SetCoefficient(vars_cache[(0.0, prob[1])], prob[0])

# %%
cf_fair_stratum.basis_status
# Out:
# <bound method Constraint.basis_status of <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x7f9198042f60> >>

# %%
solver.NumConstraints()
# Out:
# 194

# %% [markdown]
# ## Solve linear program

# %%
constrain_graduate = solver.Constraint(0, 0)

for ix, row in dff.iterrows():
    
    key = (row['R'],row['T'])
    n_graduate = row['Y'] * row['N']
    constrain_graduate.SetCoefficient(vars_cache[key], float(n_graduate))

constrain_black_admit = solver.Constraint(0, 0)

for ix, row in dff.iterrows():
    key = (row['R'],row['T'])
    n_black = row['R'] * row['N']
    constrain_black_admit.SetCoefficient(vars_cache[key], float(n_black))

# %%
count = 0 

print ('Total grid cells to check: {}'.format(len(outcomes_grid)))

for region in outcomes_grid:
    constrain_graduate.SetBounds(float(region['min_graduates']), float(region['max_graduates']))
    constrain_black_admit.SetBounds(float(region['min_black_admits']), float(region['max_black_admits']))
    status = solver.Solve()
    count+=1
    if count % 100 ==0:
        print ('Total grid cells checked so far: {}/{}'.format(count,len(outcomes_grid)))

    if status == 0:
        region['policy_exists'] = 1
        
        row = []
        admit = []

        for i in applicant_stratum:
            row.append(int(str(i)))
            admit.append(i.solution_value())
        #df_decisions = pd.DataFrame({'row_id':row,'decision':admit})
        region['policy'] = (row,admit)    
    else:
        continue
        #print(status)
# Out:
# Total grid cells to check: 63295
# Total grid cells checked so far: 100/63295
# Total grid cells checked so far: 200/63295
# Total grid cells checked so far: 300/63295
# Total grid cells checked so far: 400/63295
# Total grid cells checked so far: 500/63295
# Total grid cells checked so far: 600/63295
# Total grid cells checked so far: 700/63295
# Total grid cells checked so far: 800/63295
# Total grid cells checked so far: 900/63295
# Total grid cells checked so far: 1000/63295
# Total grid cells checked so far: 1100/63295
# Total grid cells checked so far: 1200/63295
# Total grid cells checked so far: 1300/63295
# Total grid cells checked so far: 1400/63295
# Total grid cells checked so far: 1500/63295
# Total grid cells checked so far: 1600/63295
# Total grid cells checked so far: 1700/63295
# Total grid cells checked so far: 1800/63295
# Total grid cells checked so far: 1900/63295
# Total grid cells checked so far: 2000/63295
# Total grid cells checked so far: 2100/63295
# Total grid cells checked so far: 2200/63295
# Total grid cells checked so far: 2300/63295
# Total grid cells checked so far: 2400/63295
# Total grid cells checked so far: 2500/63295
# Total grid cells checked so far: 2600/63295
# Total grid cells checked so far: 2700/63295
# Total grid cells checked so far: 2800/63295
# Total grid cells checked so far: 2900/63295
# Total grid cells checked so far: 3000/63295
# Total grid cells checked so far: 3100/63295
# Total grid cells checked so far: 3200/63295
# Total grid cells checked so far: 3300/63295
# Total grid cells checked so far: 3400/63295
# Total grid cells checked so far: 3500/63295
# Total grid cells checked so far: 3600/63295
# Total grid cells checked so far: 3700/63295
# Total grid cells checked so far: 3800/63295
# Total grid cells checked so far: 3900/63295
# Total grid cells checked so far: 4000/63295
# Total grid cells checked so far: 4100/63295
# Total grid cells checked so far: 4200/63295
# Total grid cells checked so far: 4300/63295
# Total grid cells checked so far: 4400/63295
# Total grid cells checked so far: 4500/63295
# Total grid cells checked so far: 4600/63295
# Total grid cells checked so far: 4700/63295
# Total grid cells checked so far: 4800/63295
# Total grid cells checked so far: 4900/63295
# Total grid cells checked so far: 5000/63295
# Total grid cells checked so far: 5100/63295
# Total grid cells checked so far: 5200/63295
# Total grid cells checked so far: 5300/63295
# Total grid cells checked so far: 5400/63295
# Total grid cells checked so far: 5500/63295
# Total grid cells checked so far: 5600/63295
# Total grid cells checked so far: 5700/63295
# Total grid cells checked so far: 5800/63295
# Total grid cells checked so far: 5900/63295
# Total grid cells checked so far: 6000/63295
# Total grid cells checked so far: 6100/63295
# Total grid cells checked so far: 6200/63295
# Total grid cells checked so far: 6300/63295
# Total grid cells checked so far: 6400/63295
# Total grid cells checked so far: 6500/63295
# Total grid cells checked so far: 6600/63295
# Total grid cells checked so far: 6700/63295
# Total grid cells checked so far: 6800/63295
# Total grid cells checked so far: 6900/63295
# Total grid cells checked so far: 7000/63295
# Total grid cells checked so far: 7100/63295
# Total grid cells checked so far: 7200/63295
# Total grid cells checked so far: 7300/63295
# Total grid cells checked so far: 7400/63295
# Total grid cells checked so far: 7500/63295
# Total grid cells checked so far: 7600/63295
# Total grid cells checked so far: 7700/63295
# Total grid cells checked so far: 7800/63295
# Total grid cells checked so far: 7900/63295
# Total grid cells checked so far: 8000/63295
# Total grid cells checked so far: 8100/63295
# Total grid cells checked so far: 8200/63295
# Total grid cells checked so far: 8300/63295
# Total grid cells checked so far: 8400/63295
# Total grid cells checked so far: 8500/63295
# Total grid cells checked so far: 8600/63295
# Total grid cells checked so far: 8700/63295
# Total grid cells checked so far: 8800/63295
# Total grid cells checked so far: 8900/63295
# Total grid cells checked so far: 9000/63295
# Total grid cells checked so far: 9100/63295
# Total grid cells checked so far: 9200/63295
# Total grid cells checked so far: 9300/63295
# Total grid cells checked so far: 9400/63295
# Total grid cells checked so far: 9500/63295
# Total grid cells checked so far: 9600/63295
# Total grid cells checked so far: 9700/63295
# Total grid cells checked so far: 9800/63295
# Total grid cells checked so far: 9900/63295
# Total grid cells checked so far: 10000/63295
# Total grid cells checked so far: 10100/63295
# Total grid cells checked so far: 10200/63295
# Total grid cells checked so far: 10300/63295
# Total grid cells checked so far: 10400/63295
# Total grid cells checked so far: 10500/63295
# Total grid cells checked so far: 10600/63295
# Total grid cells checked so far: 10700/63295
# Total grid cells checked so far: 10800/63295
# Total grid cells checked so far: 10900/63295
# Total grid cells checked so far: 11000/63295
# Total grid cells checked so far: 11100/63295
# Total grid cells checked so far: 11200/63295
# Total grid cells checked so far: 11300/63295
# Total grid cells checked so far: 11400/63295
# Total grid cells checked so far: 11500/63295
# Total grid cells checked so far: 11600/63295
# Total grid cells checked so far: 11700/63295
# Total grid cells checked so far: 11800/63295
# Total grid cells checked so far: 11900/63295
# Total grid cells checked so far: 12000/63295
# Total grid cells checked so far: 12100/63295
# Total grid cells checked so far: 12200/63295
# Total grid cells checked so far: 12300/63295
# Total grid cells checked so far: 12400/63295
# Total grid cells checked so far: 12500/63295
# Total grid cells checked so far: 12600/63295
# Total grid cells checked so far: 12700/63295
# Total grid cells checked so far: 12800/63295
# Total grid cells checked so far: 12900/63295
# Total grid cells checked so far: 13000/63295
# Total grid cells checked so far: 13100/63295
# Total grid cells checked so far: 13200/63295
# Total grid cells checked so far: 13300/63295
# Total grid cells checked so far: 13400/63295
# Total grid cells checked so far: 13500/63295
# Total grid cells checked so far: 13600/63295
# Total grid cells checked so far: 13700/63295
# Total grid cells checked so far: 13800/63295
# Total grid cells checked so far: 13900/63295
# Total grid cells checked so far: 14000/63295
# Total grid cells checked so far: 14100/63295
# Total grid cells checked so far: 14200/63295
# Total grid cells checked so far: 14300/63295
# Total grid cells checked so far: 14400/63295
# Total grid cells checked so far: 14500/63295
# Total grid cells checked so far: 14600/63295
# Total grid cells checked so far: 14700/63295
# Total grid cells checked so far: 14800/63295
# Total grid cells checked so far: 14900/63295
# Total grid cells checked so far: 15000/63295
# Total grid cells checked so far: 15100/63295
# Total grid cells checked so far: 15200/63295
# Total grid cells checked so far: 15300/63295
# Total grid cells checked so far: 15400/63295
# Total grid cells checked so far: 15500/63295
# Total grid cells checked so far: 15600/63295
# Total grid cells checked so far: 15700/63295
# Total grid cells checked so far: 15800/63295
# Total grid cells checked so far: 15900/63295
# Total grid cells checked so far: 16000/63295
# Total grid cells checked so far: 16100/63295
# Total grid cells checked so far: 16200/63295
# Total grid cells checked so far: 16300/63295
# Total grid cells checked so far: 16400/63295
# Total grid cells checked so far: 16500/63295
# Total grid cells checked so far: 16600/63295
# Total grid cells checked so far: 16700/63295
# Total grid cells checked so far: 16800/63295
# Total grid cells checked so far: 16900/63295
# Total grid cells checked so far: 17000/63295
# Total grid cells checked so far: 17100/63295
# Total grid cells checked so far: 17200/63295
# Total grid cells checked so far: 17300/63295
# Total grid cells checked so far: 17400/63295
# Total grid cells checked so far: 17500/63295
# Total grid cells checked so far: 17600/63295
# Total grid cells checked so far: 17700/63295
# Total grid cells checked so far: 17800/63295
# Total grid cells checked so far: 17900/63295
# Total grid cells checked so far: 18000/63295
# Total grid cells checked so far: 18100/63295
# Total grid cells checked so far: 18200/63295
# Total grid cells checked so far: 18300/63295
# Total grid cells checked so far: 18400/63295
# Total grid cells checked so far: 18500/63295
# Total grid cells checked so far: 18600/63295
# Total grid cells checked so far: 18700/63295
# Total grid cells checked so far: 18800/63295
# Total grid cells checked so far: 18900/63295
# Total grid cells checked so far: 19000/63295
# Total grid cells checked so far: 19100/63295
# Total grid cells checked so far: 19200/63295
# Total grid cells checked so far: 19300/63295
# Total grid cells checked so far: 19400/63295
# Total grid cells checked so far: 19500/63295
# Total grid cells checked so far: 19600/63295
# Total grid cells checked so far: 19700/63295
# Total grid cells checked so far: 19800/63295
# Total grid cells checked so far: 19900/63295
# Total grid cells checked so far: 20000/63295
# Total grid cells checked so far: 20100/63295
# Total grid cells checked so far: 20200/63295
# Total grid cells checked so far: 20300/63295
# Total grid cells checked so far: 20400/63295
# Total grid cells checked so far: 20500/63295
# Total grid cells checked so far: 20600/63295
# Total grid cells checked so far: 20700/63295
# Total grid cells checked so far: 20800/63295
# Total grid cells checked so far: 20900/63295
# Total grid cells checked so far: 21000/63295
# Total grid cells checked so far: 21100/63295
# Total grid cells checked so far: 21200/63295
# Total grid cells checked so far: 21300/63295
# Total grid cells checked so far: 21400/63295
# Total grid cells checked so far: 21500/63295
# Total grid cells checked so far: 21600/63295
# Total grid cells checked so far: 21700/63295
# Total grid cells checked so far: 21800/63295
# Total grid cells checked so far: 21900/63295
# Total grid cells checked so far: 22000/63295
# Total grid cells checked so far: 22100/63295
# Total grid cells checked so far: 22200/63295
# Total grid cells checked so far: 22300/63295
# Total grid cells checked so far: 22400/63295
# Total grid cells checked so far: 22500/63295
# Total grid cells checked so far: 22600/63295
# Total grid cells checked so far: 22700/63295
# Total grid cells checked so far: 22800/63295
# Total grid cells checked so far: 22900/63295
# Total grid cells checked so far: 23000/63295
# Total grid cells checked so far: 23100/63295
# Total grid cells checked so far: 23200/63295
# Total grid cells checked so far: 23300/63295
# Total grid cells checked so far: 23400/63295
# Total grid cells checked so far: 23500/63295
# Total grid cells checked so far: 23600/63295
# Total grid cells checked so far: 23700/63295
# Total grid cells checked so far: 23800/63295
# Total grid cells checked so far: 23900/63295
# Total grid cells checked so far: 24000/63295
# Total grid cells checked so far: 24100/63295
# Total grid cells checked so far: 24200/63295
# Total grid cells checked so far: 24300/63295
# Total grid cells checked so far: 24400/63295
# Total grid cells checked so far: 24500/63295
# Total grid cells checked so far: 24600/63295
# Total grid cells checked so far: 24700/63295
# Total grid cells checked so far: 24800/63295
# Total grid cells checked so far: 24900/63295
# Total grid cells checked so far: 25000/63295
# Total grid cells checked so far: 25100/63295
# Total grid cells checked so far: 25200/63295
# Total grid cells checked so far: 25300/63295
# Total grid cells checked so far: 25400/63295
# Total grid cells checked so far: 25500/63295
# Total grid cells checked so far: 25600/63295
# Total grid cells checked so far: 25700/63295
# Total grid cells checked so far: 25800/63295
# Total grid cells checked so far: 25900/63295
# Total grid cells checked so far: 26000/63295
# Total grid cells checked so far: 26100/63295
# Total grid cells checked so far: 26200/63295
# Total grid cells checked so far: 26300/63295
# Total grid cells checked so far: 26400/63295
# Total grid cells checked so far: 26500/63295
# Total grid cells checked so far: 26600/63295
# Total grid cells checked so far: 26700/63295
# Total grid cells checked so far: 26800/63295
# Total grid cells checked so far: 26900/63295
# Total grid cells checked so far: 27000/63295
# Total grid cells checked so far: 27100/63295
# Total grid cells checked so far: 27200/63295
# Total grid cells checked so far: 27300/63295
# Total grid cells checked so far: 27400/63295
# Total grid cells checked so far: 27500/63295
# Total grid cells checked so far: 27600/63295
# Total grid cells checked so far: 27700/63295
# Total grid cells checked so far: 27800/63295
# Total grid cells checked so far: 27900/63295
# Total grid cells checked so far: 28000/63295
# Total grid cells checked so far: 28100/63295
# Total grid cells checked so far: 28200/63295
# Total grid cells checked so far: 28300/63295
# Total grid cells checked so far: 28400/63295
# Total grid cells checked so far: 28500/63295
# Total grid cells checked so far: 28600/63295
# Total grid cells checked so far: 28700/63295
# Total grid cells checked so far: 28800/63295
# Total grid cells checked so far: 28900/63295
# Total grid cells checked so far: 29000/63295
# Total grid cells checked so far: 29100/63295
# Total grid cells checked so far: 29200/63295
# Total grid cells checked so far: 29300/63295
# Total grid cells checked so far: 29400/63295
# Total grid cells checked so far: 29500/63295
# Total grid cells checked so far: 29600/63295
# Total grid cells checked so far: 29700/63295
# Total grid cells checked so far: 29800/63295
# Total grid cells checked so far: 29900/63295
# Total grid cells checked so far: 30000/63295
# Total grid cells checked so far: 30100/63295
# Total grid cells checked so far: 30200/63295
# Total grid cells checked so far: 30300/63295
# Total grid cells checked so far: 30400/63295
# Total grid cells checked so far: 30500/63295
# Total grid cells checked so far: 30600/63295
# Total grid cells checked so far: 30700/63295
# Total grid cells checked so far: 30800/63295
# Total grid cells checked so far: 30900/63295
# Total grid cells checked so far: 31000/63295
# Total grid cells checked so far: 31100/63295
# Total grid cells checked so far: 31200/63295
# Total grid cells checked so far: 31300/63295
# Total grid cells checked so far: 31400/63295
# Total grid cells checked so far: 31500/63295
# Total grid cells checked so far: 31600/63295
# Total grid cells checked so far: 31700/63295
# Total grid cells checked so far: 31800/63295
# Total grid cells checked so far: 31900/63295
# Total grid cells checked so far: 32000/63295
# Total grid cells checked so far: 32100/63295
# Total grid cells checked so far: 32200/63295
# Total grid cells checked so far: 32300/63295
# Total grid cells checked so far: 32400/63295
# Total grid cells checked so far: 32500/63295
# Total grid cells checked so far: 32600/63295
# Total grid cells checked so far: 32700/63295
# Total grid cells checked so far: 32800/63295
# Total grid cells checked so far: 32900/63295
# Total grid cells checked so far: 33000/63295
# Total grid cells checked so far: 33100/63295
# Total grid cells checked so far: 33200/63295
# Total grid cells checked so far: 33300/63295
# Total grid cells checked so far: 33400/63295
# Total grid cells checked so far: 33500/63295
# Total grid cells checked so far: 33600/63295
# Total grid cells checked so far: 33700/63295
# Total grid cells checked so far: 33800/63295
# Total grid cells checked so far: 33900/63295
# Total grid cells checked so far: 34000/63295
# Total grid cells checked so far: 34100/63295
# Total grid cells checked so far: 34200/63295
# Total grid cells checked so far: 34300/63295
# Total grid cells checked so far: 34400/63295
# Total grid cells checked so far: 34500/63295
# Total grid cells checked so far: 34600/63295
# Total grid cells checked so far: 34700/63295
# Total grid cells checked so far: 34800/63295
# Total grid cells checked so far: 34900/63295
# Total grid cells checked so far: 35000/63295
# Total grid cells checked so far: 35100/63295
# Total grid cells checked so far: 35200/63295
# Total grid cells checked so far: 35300/63295
# Total grid cells checked so far: 35400/63295
# Total grid cells checked so far: 35500/63295
# Total grid cells checked so far: 35600/63295
# Total grid cells checked so far: 35700/63295
# Total grid cells checked so far: 35800/63295
# Total grid cells checked so far: 35900/63295
# Total grid cells checked so far: 36000/63295
# Total grid cells checked so far: 36100/63295
# Total grid cells checked so far: 36200/63295
# Total grid cells checked so far: 36300/63295
# Total grid cells checked so far: 36400/63295
# Total grid cells checked so far: 36500/63295
# Total grid cells checked so far: 36600/63295
# Total grid cells checked so far: 36700/63295
# Total grid cells checked so far: 36800/63295
# Total grid cells checked so far: 36900/63295
# Total grid cells checked so far: 37000/63295
# Total grid cells checked so far: 37100/63295
# Total grid cells checked so far: 37200/63295
# Total grid cells checked so far: 37300/63295
# Total grid cells checked so far: 37400/63295
# Total grid cells checked so far: 37500/63295
# Total grid cells checked so far: 37600/63295
# Total grid cells checked so far: 37700/63295
# Total grid cells checked so far: 37800/63295
# Total grid cells checked so far: 37900/63295
# Total grid cells checked so far: 38000/63295
# Total grid cells checked so far: 38100/63295
# Total grid cells checked so far: 38200/63295
# Total grid cells checked so far: 38300/63295
# Total grid cells checked so far: 38400/63295
# Total grid cells checked so far: 38500/63295
# Total grid cells checked so far: 38600/63295
# Total grid cells checked so far: 38700/63295
# Total grid cells checked so far: 38800/63295
# Total grid cells checked so far: 38900/63295
# Total grid cells checked so far: 39000/63295
# Total grid cells checked so far: 39100/63295
# Total grid cells checked so far: 39200/63295
# Total grid cells checked so far: 39300/63295
# Total grid cells checked so far: 39400/63295
# Total grid cells checked so far: 39500/63295
# Total grid cells checked so far: 39600/63295
# Total grid cells checked so far: 39700/63295
# Total grid cells checked so far: 39800/63295
# Total grid cells checked so far: 39900/63295
# Total grid cells checked so far: 40000/63295
# Total grid cells checked so far: 40100/63295
# Total grid cells checked so far: 40200/63295
# Total grid cells checked so far: 40300/63295
# Total grid cells checked so far: 40400/63295
# Total grid cells checked so far: 40500/63295
# Total grid cells checked so far: 40600/63295
# Total grid cells checked so far: 40700/63295
# Total grid cells checked so far: 40800/63295
# Total grid cells checked so far: 40900/63295
# Total grid cells checked so far: 41000/63295
# Total grid cells checked so far: 41100/63295
# Total grid cells checked so far: 41200/63295
# Total grid cells checked so far: 41300/63295
# Total grid cells checked so far: 41400/63295
# Total grid cells checked so far: 41500/63295
# Total grid cells checked so far: 41600/63295
# Total grid cells checked so far: 41700/63295
# Total grid cells checked so far: 41800/63295
# Total grid cells checked so far: 41900/63295
# Total grid cells checked so far: 42000/63295
# Total grid cells checked so far: 42100/63295
# Total grid cells checked so far: 42200/63295
# Total grid cells checked so far: 42300/63295
# Total grid cells checked so far: 42400/63295
# Total grid cells checked so far: 42500/63295
# Total grid cells checked so far: 42600/63295
# Total grid cells checked so far: 42700/63295
# Total grid cells checked so far: 42800/63295
# Total grid cells checked so far: 42900/63295
# Total grid cells checked so far: 43000/63295
# Total grid cells checked so far: 43100/63295
# Total grid cells checked so far: 43200/63295
# Total grid cells checked so far: 43300/63295
# Total grid cells checked so far: 43400/63295
# Total grid cells checked so far: 43500/63295
# Total grid cells checked so far: 43600/63295
# Total grid cells checked so far: 43700/63295
# Total grid cells checked so far: 43800/63295
# Total grid cells checked so far: 43900/63295
# Total grid cells checked so far: 44000/63295
# Total grid cells checked so far: 44100/63295
# Total grid cells checked so far: 44200/63295
# Total grid cells checked so far: 44300/63295
# Total grid cells checked so far: 44400/63295
# Total grid cells checked so far: 44500/63295
# Total grid cells checked so far: 44600/63295
# Total grid cells checked so far: 44700/63295
# Total grid cells checked so far: 44800/63295
# Total grid cells checked so far: 44900/63295
# Total grid cells checked so far: 45000/63295
# Total grid cells checked so far: 45100/63295
# Total grid cells checked so far: 45200/63295
# Total grid cells checked so far: 45300/63295
# Total grid cells checked so far: 45400/63295
# Total grid cells checked so far: 45500/63295
# Total grid cells checked so far: 45600/63295
# Total grid cells checked so far: 45700/63295
# Total grid cells checked so far: 45800/63295
# Total grid cells checked so far: 45900/63295
# Total grid cells checked so far: 46000/63295
# Total grid cells checked so far: 46100/63295
# Total grid cells checked so far: 46200/63295
# Total grid cells checked so far: 46300/63295
# Total grid cells checked so far: 46400/63295
# Total grid cells checked so far: 46500/63295
# Total grid cells checked so far: 46600/63295
# Total grid cells checked so far: 46700/63295
# Total grid cells checked so far: 46800/63295
# Total grid cells checked so far: 46900/63295
# Total grid cells checked so far: 47000/63295
# Total grid cells checked so far: 47100/63295
# Total grid cells checked so far: 47200/63295
# Total grid cells checked so far: 47300/63295
# Total grid cells checked so far: 47400/63295
# Total grid cells checked so far: 47500/63295
# Total grid cells checked so far: 47600/63295
# Total grid cells checked so far: 47700/63295
# Total grid cells checked so far: 47800/63295
# Total grid cells checked so far: 47900/63295
# Total grid cells checked so far: 48000/63295
# Total grid cells checked so far: 48100/63295
# Total grid cells checked so far: 48200/63295
# Total grid cells checked so far: 48300/63295
# Total grid cells checked so far: 48400/63295
# Total grid cells checked so far: 48500/63295
# Total grid cells checked so far: 48600/63295
# Total grid cells checked so far: 48700/63295
# Total grid cells checked so far: 48800/63295
# Total grid cells checked so far: 48900/63295
# Total grid cells checked so far: 49000/63295
# Total grid cells checked so far: 49100/63295
# Total grid cells checked so far: 49200/63295
# Total grid cells checked so far: 49300/63295
# Total grid cells checked so far: 49400/63295
# Total grid cells checked so far: 49500/63295
# Total grid cells checked so far: 49600/63295
# Total grid cells checked so far: 49700/63295
# Total grid cells checked so far: 49800/63295
# Total grid cells checked so far: 49900/63295
# Total grid cells checked so far: 50000/63295
# Total grid cells checked so far: 50100/63295
# Total grid cells checked so far: 50200/63295
# Total grid cells checked so far: 50300/63295
# Total grid cells checked so far: 50400/63295
# Total grid cells checked so far: 50500/63295
# Total grid cells checked so far: 50600/63295
# Total grid cells checked so far: 50700/63295
# Total grid cells checked so far: 50800/63295
# Total grid cells checked so far: 50900/63295
# Total grid cells checked so far: 51000/63295
# Total grid cells checked so far: 51100/63295
# Total grid cells checked so far: 51200/63295
# Total grid cells checked so far: 51300/63295
# Total grid cells checked so far: 51400/63295
# Total grid cells checked so far: 51500/63295
# Total grid cells checked so far: 51600/63295
# Total grid cells checked so far: 51700/63295
# Total grid cells checked so far: 51800/63295
# Total grid cells checked so far: 51900/63295
# Total grid cells checked so far: 52000/63295
# Total grid cells checked so far: 52100/63295
# Total grid cells checked so far: 52200/63295
# Total grid cells checked so far: 52300/63295
# Total grid cells checked so far: 52400/63295
# Total grid cells checked so far: 52500/63295
# Total grid cells checked so far: 52600/63295
# Total grid cells checked so far: 52700/63295
# Total grid cells checked so far: 52800/63295
# Total grid cells checked so far: 52900/63295
# Total grid cells checked so far: 53000/63295
# Total grid cells checked so far: 53100/63295
# Total grid cells checked so far: 53200/63295
# Total grid cells checked so far: 53300/63295
# Total grid cells checked so far: 53400/63295
# Total grid cells checked so far: 53500/63295
# Total grid cells checked so far: 53600/63295
# Total grid cells checked so far: 53700/63295
# Total grid cells checked so far: 53800/63295
# Total grid cells checked so far: 53900/63295
# Total grid cells checked so far: 54000/63295
# Total grid cells checked so far: 54100/63295
# Total grid cells checked so far: 54200/63295
# Total grid cells checked so far: 54300/63295
# Total grid cells checked so far: 54400/63295
# Total grid cells checked so far: 54500/63295
# Total grid cells checked so far: 54600/63295
# Total grid cells checked so far: 54700/63295
# Total grid cells checked so far: 54800/63295
# Total grid cells checked so far: 54900/63295
# Total grid cells checked so far: 55000/63295
# Total grid cells checked so far: 55100/63295
# Total grid cells checked so far: 55200/63295
# Total grid cells checked so far: 55300/63295
# Total grid cells checked so far: 55400/63295
# Total grid cells checked so far: 55500/63295
# Total grid cells checked so far: 55600/63295
# Total grid cells checked so far: 55700/63295
# Total grid cells checked so far: 55800/63295
# Total grid cells checked so far: 55900/63295
# Total grid cells checked so far: 56000/63295
# Total grid cells checked so far: 56100/63295
# Total grid cells checked so far: 56200/63295
# Total grid cells checked so far: 56300/63295
# Total grid cells checked so far: 56400/63295
# Total grid cells checked so far: 56500/63295
# Total grid cells checked so far: 56600/63295
# Total grid cells checked so far: 56700/63295
# Total grid cells checked so far: 56800/63295
# Total grid cells checked so far: 56900/63295
# Total grid cells checked so far: 57000/63295
# Total grid cells checked so far: 57100/63295
# Total grid cells checked so far: 57200/63295
# Total grid cells checked so far: 57300/63295
# Total grid cells checked so far: 57400/63295
# Total grid cells checked so far: 57500/63295
# Total grid cells checked so far: 57600/63295
# Total grid cells checked so far: 57700/63295
# Total grid cells checked so far: 57800/63295
# Total grid cells checked so far: 57900/63295
# Total grid cells checked so far: 58000/63295
# Total grid cells checked so far: 58100/63295
# Total grid cells checked so far: 58200/63295
# Total grid cells checked so far: 58300/63295
# Total grid cells checked so far: 58400/63295
# Total grid cells checked so far: 58500/63295
# Total grid cells checked so far: 58600/63295
# Total grid cells checked so far: 58700/63295
# Total grid cells checked so far: 58800/63295
# Total grid cells checked so far: 58900/63295
# Total grid cells checked so far: 59000/63295
# Total grid cells checked so far: 59100/63295
# Total grid cells checked so far: 59200/63295
# Total grid cells checked so far: 59300/63295
# Total grid cells checked so far: 59400/63295
# Total grid cells checked so far: 59500/63295
# Total grid cells checked so far: 59600/63295
# Total grid cells checked so far: 59700/63295
# Total grid cells checked so far: 59800/63295
# Total grid cells checked so far: 59900/63295
# Total grid cells checked so far: 60000/63295
# Total grid cells checked so far: 60100/63295
# Total grid cells checked so far: 60200/63295
# Total grid cells checked so far: 60300/63295
# Total grid cells checked so far: 60400/63295
# Total grid cells checked so far: 60500/63295
# Total grid cells checked so far: 60600/63295
# Total grid cells checked so far: 60700/63295
# Total grid cells checked so far: 60800/63295
# Total grid cells checked so far: 60900/63295
# Total grid cells checked so far: 61000/63295
# Total grid cells checked so far: 61100/63295
# Total grid cells checked so far: 61200/63295
# Total grid cells checked so far: 61300/63295
# Total grid cells checked so far: 61400/63295
# Total grid cells checked so far: 61500/63295
# Total grid cells checked so far: 61600/63295
# Total grid cells checked so far: 61700/63295
# Total grid cells checked so far: 61800/63295
# Total grid cells checked so far: 61900/63295
# Total grid cells checked so far: 62000/63295
# Total grid cells checked so far: 62100/63295
# Total grid cells checked so far: 62200/63295
# Total grid cells checked so far: 62300/63295
# Total grid cells checked so far: 62400/63295
# Total grid cells checked so far: 62500/63295
# Total grid cells checked so far: 62600/63295
# Total grid cells checked so far: 62700/63295
# Total grid cells checked so far: 62800/63295
# Total grid cells checked so far: 62900/63295
# Total grid cells checked so far: 63000/63295
# Total grid cells checked so far: 63100/63295
# Total grid cells checked so far: 63200/63295

# %%
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.patches import Rectangle
from matplotlib.collections import PatchCollection

sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(style="white", font_scale=1.5, )
ax = sns.lineplot(data=df_pareto, x='# Black Admits', y='# Graduates',linewidth=5)
errorboxes = []

for outcome_block in outcomes_grid:
    if outcome_block['policy_exists'] == 1:
        errorboxes.append(Rectangle((outcome_block['min_black_admits'] , outcome_block['min_graduates']),GRID_SIZE,GRID_SIZE))

pc = PatchCollection(errorboxes, facecolor='red', alpha=0.5,  edgecolor='none')
                       
ax.add_collection(pc)
plt.scatter(x=(df['R']*0.5).sum(),y=(df['Y']*0.5).sum(),color='green')   
plt.xlim([0, MAX_BLACK_ADMITS])
plt.ylim([df_pareto['# Graduates'].min()-2000, df_pareto['# Graduates'].max()+1000])
plt.show()
